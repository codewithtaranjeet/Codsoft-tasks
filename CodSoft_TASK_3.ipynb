# %% [markdown]
# # Task3: CREDIT CARD FRAUD DETECTION WITH PYTHON
# ####  By TARANJEET KAUR
# ####  FEB Batch, Domain: Data Science
# ####  Objective: To Build a machine learning model to identify fraudulent credit card transactions.

# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv("C:/Users/Taranjeet Kaur/Downloads/creditcard.csv/creditcard.csv", encoding='ISO-8859-1')

# %%
df.head(7)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# ...

# %% [markdown]
# ## Data filtering and preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ## Distribution of real and fraud transactions

# %%
real = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print(real.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
real.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# ## Under Sampling

# %%
real_sample = real.sample(n=492)

# %%
new_df = pd.concat([real_sample, fraud], axis=0)

# %%
new_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 95292    65242.0 -0.631701  1.049422  1.452194  2.576940  0.534141 -0.231687
# 28155    34879.0 -2.107661  1.089782  1.580844  1.128106 -0.209787  3.291074
# 141801   84496.0  1.304953 -0.443103  0.541756 -0.910183 -0.895507 -0.376930
# 149529   91416.0  1.963936 -0.161621 -0.939007  0.529377 -0.109439 -0.951444
# 166555  118157.0 -0.173895  0.834185  2.651017  4.514929  0.136188  0.973530
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 95292   0.583737 -0.103133 -1.418305  ...  0.191249  0.602310  0.204187
# 28155  -1.739580 -1.238199 -0.408145  ... -1.251701  0.809315 -0.022795
# 141801 -0.657119  0.075359  2.030216  ... -0.078824 -0.020759 -0.127974
# 149529  0.110689 -0.487212  2.156715  ... -0.022441  0.501608 -0.013614
# 166555 -0.203066  0.133586 -1.132918  ...  0.061944  0.386792 -0.017408
#
# ...

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# ## Splitting the data into features and targets

# %%
x = new_df.drop(columns='Class', axis = 1)
y = new_df['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 95292    65242.0 -0.631701  1.049422  1.452194  2.576940  0.534141 -0.231687
# 28155    34879.0 -2.107661  1.089782  1.580844  1.128106 -0.209787  3.291074
# 141801   84496.0  1.304953 -0.443103  0.541756 -0.910183 -0.895507 -0.376930
# 149529   91416.0  1.963936 -0.161621 -0.939007  0.529377 -0.109439 -0.951444
# 166555  118157.0 -0.173895  0.834185  2.651017  4.514929  0.136188  0.973530
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(y)
# Out:
# 95292     0
# 28155     0
# 141801    0
# 149529    0
# 166555    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Splitting the data into training data and test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, stratify=y, random_state = 2)

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Accuracy Score

# %%
x_train_prediction = lr.predict(x_train)
train_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print(train_data_accuracy)
# Out:
# 0.9415501905972046

# %%
x_test_prediction = lr.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print(test_data_accuracy)
# Out:
# 0.9187817258883249
